# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("C:/Users/Aishwarya/Desktop/DAR/insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sorted_df = df.sort_values(by='age', ascending=True)
sorted_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 482    18  female  31.350         0     no  southeast   1622.18850
# 492    18  female  25.080         0     no  northeast   2196.47320
# 525    18  female  33.880         0     no  southeast  11482.63485
# 529    18    male  25.460         0     no  northeast   1708.00140
# ...   ...     ...     ...       ...    ...        ...          ...
# 398    64    male  25.600         2     no  southwest  14988.43200
# 335    64    male  34.500         0     no  southwest  13822.80300
# 378    64  female  30.115         3     no  northwest  16455.70785
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 635    64    male  38.190         0     no  northeast  14410.93210
#
# [1338 rows x 7 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
#dropping the duplicates
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df["sex"].value_counts()
# Out:
# sex
# 1    676
# 0    662
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#sex
le = LabelEncoder()
le.fit(df.sex.drop_duplicates()) 
df.sex = le.transform(df.sex)
# smoker or not
le.fit(df.smoker.drop_duplicates()) 
df.smoker = le.transform(df.smoker)
#region
le.fit(df.region.drop_duplicates()) 
df.region = le.transform(df.region)

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.histplot(data=df, x="age", kde=True,bins=range(15, 70,2 ))#awing a histogram to see which age is the more number present in thr dataset
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
le.fit(df.sex.drop_duplicates())

df.sex =le.transform(df.sex)
le.fit(df.region.drop_duplicates())

df.region =le.transform(df.region)
le.fit(df.smoker.drop_duplicates())
df.smoker=le.transform(df.smoker)

# %%
df.corr()["charges"]
# Out:
# age         0.299008
# sex         0.057292
# bmi         0.198341
# children    0.067998
# smoker      0.787251
# region     -0.006208
# charges     1.000000
# Name: charges, dtype: float64

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(),annot=True,fmt=".1f",linewidth=.5);
#smoker and charges are co-related to each oher
# Out:
# /var/folders/tq/bjtswj5j7hs12301nqgdbvsm0000gn/T/ipykernel_947/1260679656.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt=".1f",linewidth=.5);

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# /var/folders/tq/bjtswj5j7hs12301nqgdbvsm0000gn/T/ipykernel_947/913683276.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # histplot

# %%
sns.histplot(df["charges"],kde=True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot( y=df["charges"])
# Out:
# <Axes: xlabel='Count', ylabel='charges'>

# %%
sns.displot(x=df["age"],kind="hist")

# %%
sns.histplot(df["age"],color='c')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # countplot

# %%
sns.countplot(df, x="smoker", hue="sex") #in non smoker female count is more, in smoker category,men are more in count, 
#it can happen men since the count is more needs more charges
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df
###Female=0,male=1
sns.catplot(x="sex", y="charges", hue="smoker", kind="boxen", data=df, palette = 'magma')
#This function provides access to several axes-level functions that show the relationship 
#between a numerical and one or more categorical variables using one of several visual representations. 
#The kind parameter selects the underlying axes-level function to use.
# Out:
# C:\Users\Aishwarya\anaconda3\ana\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Age group of smokers
#From the histplot, we see the aage around 20 they have the maximum number of people smoking, next question

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
sns.boxplot(y="smoker", x="charges", data = df[(df.age <=20)] , orient="h", palette = 'pink')
###we see that even with smaller age (<20) has high charges that spends on treatment
# Out:
# <Axes: xlabel='charges', ylabel='smoker'>

# %%
sns.histplot(df["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.scatterplot(x='bmi',y='charges',data=df,palette='magma',hue='smoker')
ax.set_title('Scatter plot of charges and bmi')
# Out:
# Text(0.5, 1.0, 'Scatter plot of charges and bmi')

# %%
sns.jointplot(data=df, x="age", y="charges",hue="smoker")

# %%
sns.scatterplot(data=df, x="age", y="charges", hue="smoker")
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.lmplot(data=df, x="age", y="charges", hue="smoker")
# Out:
# C:\Users\Aishwarya\anaconda3\ana\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df,x='age',y='bmi')
# Out:
# C:\Users\Aishwarya\anaconda3\ana\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(df,x='smoker',y='children',hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='children'>

# %%
f= plt.figure(figsize=(12,5))
ax=f.add_subplot(121)
sns.histplot(df[(df.smoker == 1)]["charges"],color='c',ax=ax)
ax.set_title('Distribution of charges for smokers')
ax=f.add_subplot(122)
sns.histplot(df[(df.smoker == 0)]["charges"],color='c',ax=ax)
ax.set_title('Distribution of charges for non-smokers')
# Out:
# Text(0.5, 1.0, 'Distribution of charges for non-smokers')

# %%
sns.lmplot(data=df, x="bmi", y="charges", hue="smoker")
# Out:
# C:\Users\Aishwarya\anaconda3\ana\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
